# %% [markdown]
# <a href="https://colab.research.google.com/github/neerajsingh9929/Machine-Learning-tutorial/blob/main/classification_of_red_wine_and_white_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# working on tenser flow
# classification of red wine and white wine

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
# !pip install tensorflow==2.0

# %%
import pandas as pd 
import numpy as np
# read in red  wine data set
red=pd.read_csv("/content/winequality-red.csv")
white=pd.read_csv("/content/winequality-white.csv")

# %%
#printing red wine info
print(red.info())
#printing white wine info
print(white.info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
# ...

# %%
white.describe()
# Out:
#        fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# count                                                4898
# unique                                               3961
# top     7.3;0.19;0.27;13.9;0.057;45;155;0.99807;2.94;0...
# freq                                                    8

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
pd.isnull(red).count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
pd.isnull(white).count()
# Out:
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    4898
# dtype: int64

# %%
# add type column inred with value 1
red['type']=1
# add type column in white with value 0
white['type']=0
wines=red.append(white,ignore_index=True)
wines.tail()
# Out:
#       fixed acidity  ...  fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 6492            NaN  ...  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 6493            NaN  ...  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 6494            NaN  ...  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 6495            NaN  ...  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 6496            NaN  ...  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [5 rows x 14 columns]

# %%
wines.head()
# Out:
#    fixed acidity  ...  fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0            7.4  ...                                                NaN
# 1            7.8  ...                                                NaN
# 2            7.8  ...                                                NaN
# 3           11.2  ...                                                NaN
# 4            7.4  ...                                                NaN
#
# [5 rows x 14 columns]

# %%
import seaborn as sns
sns.pairplot(wines,diag_kind='kde',hue='type')

# %% [markdown]
# build a model using deep nural network
